# %% [markdown]
# <a href="https://colab.research.google.com/github/goldenkick1-92/music-computing-class-work-2026/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
